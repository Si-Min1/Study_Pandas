# %% [markdown]
# # txt 파일 읽어 들이기

# %%
import pandas as pd

# %%
# 20Table
df_20TABLE = pd.read_csv("./files_org/SAMPLE_DB_20TABLE_2013.txt", sep=",")
df_20TABLE.head(1)
# Out:
#    key   no  DMD_FRM_CD  DMD_TP_CD  FOM_CD  AGG  SelectionProb  \
# 0    1  169           3          0       3   13       0.030001
#
#    SamplingWeight  PAT_AGE  SEX_TP_CD  ...  VST_DDCNT RVD_RPE_TAMT_AMT  \
# 0       33.332599     62.0          1  ...          1             9430
#
#   RVD_SLF_BRDN_AMT  RVD_INSUP_BRDN_AMT  SOPR_YN  PRCL_SYM_TP_CD  MAIDCL_CD  \
# 0             2800                6630        0               $          $
#
#   RADT_DIAG_YN  RADT_TRET_YN    yno
# 0            $             $  30796
#
# [1 rows x 32 columns]

# %%
# df_30TABLE
df_30TABLE = pd.read_csv("./files_org/SAMPLE_DB_30TABLE_2013.txt", sep=",")
df_30TABLE.head(1)
# Out:
#    key CZ_CD  ITEM_CD  DIV_TY_CD DIV_CD  SP1_SP2_TP_CD  UNPRC  FQ1_MDCT_QTY  \
# 0    1    01        2          1  AA254              1   9430           1.0
#
#    DY1_MDCT_QTY  DY1_INJC_QTY_EXEC_FQ  TOT_INJC_DDCNT_EXEC_FQ  \
# 0           1.0                   1.0                       1
#
#    TOT_USE_QTY_OR_EXEC_FQ   AMT  ADDC_ADT_AMT  LN_NO GNL_NM_CD
# 0                     1.0  9430          9430      1         $

# %%
# df_40TABLE
df_40TABLE = pd.read_csv("./files_org/SAMPLE_DB_40TABLE_2013.txt", sep=",")
df_40TABLE.head(1)
# Out:
#    key  SICK_SNO SICK_DGSBJT_CD DMD_SICK_SYM  DMD_DGSBJT_CD
# 0    1         3             01         K599              1

# %%
# df_53ABLE
df_53TABLE = pd.read_csv("./files_org/SAMPLE_DB_53TABLE_2013.txt", sep=",")
df_53TABLE.head(1)
# Out:
#    key  LN_NO  PRSCP_GRANT_NO  DIV_TY_CD  UNPRC  FQ1_MDCT_QTY  DY1_MDCT_QTY  \
# 0    1      4   2013010801012          3     80           1.0           3.0
#
#    TOT_INJC_DDCNT_EXEC_FQ  TOT_USE_QTY_OR_EXEC_FQ  AMT  GNL_NM_CD
# 0                       3                     9.0  720  294300ACS

# %% [markdown]
# # 메타정의서 컬럼명 가지고 오기

# %%
df_20TABLE_col = pd.read_excel("./files_org/표본자료 변수 테이블(2012-2013).xlsx", 
                               sheet_name = "20table_명세서일반내역",
                               usecols = "A, D")
df_20TABLE_col.head(1)
# Out:
#    변수명   표준한글컬럼명
# 0  key  명세서 연결코드

# %%
# df_30TABLE_col, df_30TABLE_col, df_53TABLE_col 모두 가지고 오기..

# %%
df_30TABLE_col = pd.read_excel("./files_org/표본자료 변수 테이블(2012-2013).xlsx", 
                               sheet_name = "30table_진료내역",
                               usecols = "A, D")
df_30TABLE_col.head(1)
# Out:
#    변수명   표준한글컬럼명
# 0  key  명세서 연결코드

# %%
df_40TABLE_col = pd.read_excel("./files_org/표본자료 변수 테이블(2012-2013).xlsx", 
                               sheet_name = "40table_상병",
                               usecols = "A, D")
df_40TABLE_col.head(1)
# Out:
#    변수명   표준한글컬럼명
# 0  key  명세서 연결코드

# %%
df_53TABLE_col = pd.read_excel("./files_org/표본자료 변수 테이블(2012-2013).xlsx", 
                               sheet_name = "53table_처방전상세내역",
                               usecols = "A, D")
df_53TABLE_col.head(1)
# Out:
#    변수명   표준한글컬럼명
# 0  key  명세서 연결코드

# %%
df_20TABLE.head(1)
# Out:
#    key   no  DMD_FRM_CD  DMD_TP_CD  FOM_CD  AGG  SelectionProb  \
# 0    1  169           3          0       3   13       0.030001
#
#    SamplingWeight  PAT_AGE  SEX_TP_CD  ...  VST_DDCNT RVD_RPE_TAMT_AMT  \
# 0       33.332599     62.0          1  ...          1             9430
#
#   RVD_SLF_BRDN_AMT  RVD_INSUP_BRDN_AMT  SOPR_YN  PRCL_SYM_TP_CD  MAIDCL_CD  \
# 0             2800                6630        0               $          $
#
#   RADT_DIAG_YN  RADT_TRET_YN    yno
# 0            $             $  30796
#
# [1 rows x 32 columns]

# %%
#df_20TABLE.rename(columns = 딕셔너리_데이터)

# %%
temp_dict = {}
temp_dict["key1"] = "value1"
temp_dict["key2"] = "value2"
temp_dict["key3"] = "value3"
print(temp_dict)

temp_dict["key2"]
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}
# 'value2'

# %%
new_dict_20 = {}
# {key' :'명세서 연결코드'}

for dict_kv in df_20TABLE_col.to_dict("records") :
    new_dict_20[dict_kv["변수명"]] = dict_kv["표준한글컬럼명"]
    
# new_dict_20
df_20TABLE_kor = df_20TABLE.rename(columns = new_dict_20)
df_20TABLE_kor.head(1)
# Out:
#    명세서 연결코드  수진자고유번호  청구형태코드  청구구분코드  서식코드  연령군      추출확률      샘플가중치  수진자연령  \
# 0         1      169       3       0     3   13  0.030001  33.332599   62.0
#
#    성별구분코드  ...  내원일수 심결요양급여비용총액 심결본인부담금  심결보험자부담금  수술여부  특정기호구분코드  의료급여종별코드  \
# 0       1  ...     1       9430    2800      6630     0         $         $
#
#   방사선진단여부  방사선치료여부 요양기관 고유번호
# 0       $        $     30796
#
# [1 rows x 32 columns]

# %%
df_30TABLE_col_list = df_30TABLE_col.to_dict("records")
# {'변수명': 'key', '표준한글컬럼명': '명세서 연결코드'}

new_dict_30 = {}
# {key' :'명세서 연결코드'}

for dict_kv in df_30TABLE_col_list :
    new_dict_30[dict_kv["변수명"]] = dict_kv["표준한글컬럼명"]
    
# new_dict_20
df_30TABLE_kor = df_30TABLE.rename(columns = new_dict_30)
df_30TABLE_kor.head(1)
# Out:
#    명세서 연결코드 항코드  목코드  분류유형코드   분류코드  1_2구분코드    단가  1회투약량  1일투약량  1일투여량실시횟수  \
# 0         1  01    2       1  AA254        1  9430    1.0    1.0        1.0
#
#    총투여일수또는실시횟수  총사용량또는실시횟수    금액  가산적용금액  줄번호 일반명코드
# 0            1         1.0  9430    9430    1     $

# %%
df_40TABLE_col_list = df_40TABLE_col.to_dict("records")
# {'변수명': 'key', '표준한글컬럼명': '명세서 연결코드'}

new_dict_40 = {}
# {key' :'명세서 연결코드'}

for dict_kv in df_40TABLE_col_list :
    new_dict_40[dict_kv["변수명"]] = dict_kv["표준한글컬럼명"]
    
# new_dict_20
df_40TABLE_kor = df_40TABLE.rename(columns = new_dict_40)
df_40TABLE_kor.head(1)
# Out:
#    명세서 연결코드  상병일련번호 상병진료과목코드 청구상병기호  청구진료과목코드
# 0         1       3       01   K599         1

# %%
df_53TABLE_col_list = df_53TABLE_col.to_dict("records")
# {'변수명': 'key', '표준한글컬럼명': '명세서 연결코드'}

new_dict_53 = {}
# {key' :'명세서 연결코드'}

for dict_kv in df_53TABLE_col_list :
    new_dict_53[dict_kv["변수명"]] = dict_kv["표준한글컬럼명"]
    
# new_dict_20
df_53TABLE_kor = df_53TABLE.rename(columns = new_dict_53)
df_53TABLE_kor.head(1)
# Out:
#    명세서 연결코드  줄번호        처방전교부번호  분류유형코드  단가  1회투약량  1일투약량  총투여일수또는실시횟수  \
# 0         1    4  2013010801012       3  80    1.0    3.0            3
#
#    총사용량또는실시횟수   금액      일반명코드
# 0         9.0  720  294300ACS

# %%
df_20TABLE_kor.to_excel("./files_new/df_20TABLE_kor_명세서일반내역.xlsx", index=False)
df_30TABLE_kor.to_excel("./files_new/df_30TABLE_kor_진료내역.xlsx", index=False)
df_40TABLE_kor.to_excel("./files_new/df_40TABLE_kor_상병.xlsx", index=False)
df_53TABLE_kor.to_excel("./files_new/df_53TABLE_kor_처방전상세내역.xlsx", index=False)

# %% [markdown]
# ### a

# %%
for dict_kv in df_col.to_dict("records") :
        new_dict[i["변수명"]] = i["표준한글컬럼명"]
    # new_dict_20
    df_kor[a] = i.rename(columns = new_dict)
    print(df_kor[a].head(1))

# %%
new_dict = {}
df_kor = []
# {key' :'명세서 연결코드'}
tbl_name = [df_20TABLE_col, df_30TABLE_col, df_40TABLE_col, df_53TABLE_col]
a = 0
for i in tbl_name:
    df_20TABLE_col[i["변수명"]] = i["표준한글컬럼명"]
df_20TABLE_col
# df_20TABLE_col
# tbl_name[0]
# Out:
#                     변수명     표준한글컬럼명       key DMD_TP_CD DMD_FRM_CD FOM_CD  \
# 0                   key    명세서 연결코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 1             DMD_TP_CD      청구구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 2            DMD_FRM_CD      청구형태코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 3                FOM_CD        서식코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 4                    no     수진자고유번호  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 5                   AGG         연령군  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 6         SelectionProb        추출확률  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 7        SamplingWeight       샘플가중치  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 8               PAT_AGE       수진자연령  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 9             SEX_TP_CD      성별구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 10          INSUP_TP_CD       보험자코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 11             MSICK_CD       주상병코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 12             SSICK_CD       부상병코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 13           RECU_FR_DD      요양개시일자  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 14           RECU_TO_DD      요양만료일자  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 15         DGRSLT_TP_CD    진료결과구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 16            DGSBJT_CD      진료과목코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 17           DMD_DRG_NO     청구DRG번호  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 18          FST_IPAT_DD      최초입원일자  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 19  IPAT_ARIV_PTH_TP_CD  입원도착경로구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 20           OINJ_TP_CD      공상구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 21           RECU_DDCNT        요양일수  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 22            VST_DDCNT        내원일수  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 23     RVD_RPE_TAMT_AMT  심결요양급여비용총액  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 24     RVD_SLF_BRDN_AMT     심결본인부담금  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 25   RVD_INSUP_BRDN_AMT    심결보험자부담금  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 26              SOPR_YN        수술여부  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 27       PRCL_SYM_TP_CD    특정기호구분코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 28            MAIDCL_CD    의료급여종별코드  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 29         RADT_DIAG_YN     방사선진단여부  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 30         RADT_TRET_YN     방사선치료여부  명세서 연결코드    청구구분코드     청구형태코드   서식코드
# 31                  yno   요양기관 고유번호  명세서 연결코드    청구구분코드     청구형태코드   서식코드
#
#          no  AGG SelectionProb SamplingWeight  ... TOT_USE_QTY_OR_EXEC_FQ AMT  \
# 0   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 1   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 2   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 3   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 4   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 5   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 6   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 7   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 8   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 9   수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 10  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 11  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 12  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 13  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 14  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 15  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 16  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 17  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 18  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 19  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 20  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 21  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 22  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 23  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 24  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 25  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 26  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 27  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 28  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 29  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 30  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
# 31  수진자고유번호  연령군          추출확률          샘플가중치  ...             총사용량또는실시횟수  금액
#
#    ADDC_ADT_AMT LN_NO GNL_NM_CD SICK_SNO SICK_DGSBJT_CD DMD_SICK_SYM  \
# 0        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 1        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 2        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 3        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 4        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 5        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 6        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 7        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 8        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 9        가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 10       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 11       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 12       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 13       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 14       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 15       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 16       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 17       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 18       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 19       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 20       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 21       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 22       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 23       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 24       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 25       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 26       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 27       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 28       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 29       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 30       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
# 31       가산적용금액   줄번호     일반명코드   상병일련번호       상병진료과목코드       청구상병기호
#
#    DMD_DGSBJT_CD PRSCP_GRANT_NO
# 0       청구진료과목코드        처방전교부번호
# 1       청구진료과목코드        처방전교부번호
# 2       청구진료과목코드        처방전교부번호
# 3       청구진료과목코드        처방전교부번호
# 4       청구진료과목코드        처방전교부번호
# 5       청구진료과목코드        처방전교부번호
# 6       청구진료과목코드        처방전교부번호
# 7       청구진료과목코드        처방전교부번호
# 8       청구진료과목코드        처방전교부번호
# 9       청구진료과목코드        처방전교부번호
# 10      청구진료과목코드        처방전교부번호
# 11      청구진료과목코드        처방전교부번호
# 12      청구진료과목코드        처방전교부번호
# 13      청구진료과목코드        처방전교부번호
# 14      청구진료과목코드        처방전교부번호
# 15      청구진료과목코드        처방전교부번호
# 16      청구진료과목코드        처방전교부번호
# 17      청구진료과목코드        처방전교부번호
# 18      청구진료과목코드        처방전교부번호
# 19      청구진료과목코드        처방전교부번호
# 20      청구진료과목코드        처방전교부번호
# 21      청구진료과목코드        처방전교부번호
# 22      청구진료과목코드        처방전교부번호
# 23      청구진료과목코드        처방전교부번호
# 24      청구진료과목코드        처방전교부번호
# 25      청구진료과목코드        처방전교부번호
# 26      청구진료과목코드        처방전교부번호
# 27      청구진료과목코드        처방전교부번호
# 28      청구진료과목코드        처방전교부번호
# 29      청구진료과목코드        처방전교부번호
# 30      청구진료과목코드        처방전교부번호
# 31      청구진료과목코드        처방전교부번호
#
# [32 rows x 54 columns]

# %%
df_OUTER_JOIN = pd.merge(df_20TABLE_col, df_30TABLE_col, on=['변수명','표준한글컬럼명'], how='outer')
df_OUTER_JOIN
# Out:
#                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                DMD_TP_CD       청구구분코드
# 2               DMD_FRM_CD       청구형태코드
# 3                   FOM_CD         서식코드
# 4                       no      수진자고유번호
# 5                      AGG          연령군
# 6            SelectionProb         추출확률
# 7           SamplingWeight        샘플가중치
# 8                  PAT_AGE        수진자연령
# 9                SEX_TP_CD       성별구분코드
# 10             INSUP_TP_CD        보험자코드
# 11                MSICK_CD        주상병코드
# 12                SSICK_CD        부상병코드
# 13              RECU_FR_DD       요양개시일자
# 14              RECU_TO_DD       요양만료일자
# 15            DGRSLT_TP_CD     진료결과구분코드
# 16               DGSBJT_CD       진료과목코드
# 17              DMD_DRG_NO      청구DRG번호
# 18             FST_IPAT_DD       최초입원일자
# 19     IPAT_ARIV_PTH_TP_CD   입원도착경로구분코드
# 20              OINJ_TP_CD       공상구분코드
# 21              RECU_DDCNT         요양일수
# 22               VST_DDCNT         내원일수
# 23        RVD_RPE_TAMT_AMT   심결요양급여비용총액
# 24        RVD_SLF_BRDN_AMT      심결본인부담금
# 25      RVD_INSUP_BRDN_AMT     심결보험자부담금
# 26                 SOPR_YN         수술여부
# 27          PRCL_SYM_TP_CD     특정기호구분코드
# 28               MAIDCL_CD     의료급여종별코드
# 29            RADT_DIAG_YN      방사선진단여부
# 30            RADT_TRET_YN      방사선치료여부
# 31                     yno    요양기관 고유번호
# 32                   CZ_CD          항코드
# 33                 ITEM_CD          목코드
# 34               DIV_TY_CD       분류유형코드
# 35                  DIV_CD         분류코드
# 36           SP1_SP2_TP_CD      1_2구분코드
# 37                   UNPRC           단가
# 38            FQ1_MDCT_QTY        1회투약량
# 39            DY1_MDCT_QTY        1일투약량
# 40    DY1_INJC_QTY_EXEC_FQ    1일투여량실시횟수
# 41  TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 42  TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 43                     AMT           금액
# 44            ADDC_ADT_AMT       가산적용금액
# 45                   LN_NO          줄번호
# 46               GNL_NM_CD        일반명코드

# %%
# 그냥 데이터 프레임 전처리해서 이걸로 합치는게 빠를듯
df_col = pd.concat([df_20TABLE_col, df_30TABLE_col, df_40TABLE_col, df_53TABLE_col], ignore_index=True)
df_col
# Out:
#                        변수명      표준한글컬럼명
# 0                      key     명세서 연결코드
# 1                DMD_TP_CD       청구구분코드
# 2               DMD_FRM_CD       청구형태코드
# 3                   FOM_CD         서식코드
# 4                       no      수진자고유번호
# ..                     ...          ...
# 59            DY1_MDCT_QTY        1일투약량
# 60  TOT_INJC_DDCNT_EXEC_FQ  총투여일수또는실시횟수
# 61  TOT_USE_QTY_OR_EXEC_FQ   총사용량또는실시횟수
# 62                     AMT           금액
# 63               GNL_NM_CD        일반명코드
#
# [64 rows x 2 columns]

# %%
test = {'key': [2,3,4], 'age': [18, 15, 20]}
test1 = {'key': [2,3,4], 'age': [19, 14, 22]}

testdf = pd.DataFrame(test, columns = ['key', 'age'])
testdf1 = pd.DataFrame(test1, columns = ['key', 'age'])

print(testdf)
print(testdf1)
pd.concat([testdf, testdf1], ignore_index = True)
# Out:
#    key  age
# 0    2   18
# 1    3   15
# 2    4   20
#    key  age
# 0    2   19
# 1    3   14
# 2    4   22
#    key  age
# 0    2   18
# 1    3   15
# 2    4   20
# 3    2   19
# 4    3   14
# 5    4   22
